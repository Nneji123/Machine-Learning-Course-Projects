# %%
import pandas as pd
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import apriori
from mlxtend.preprocessing import TransactionEncoder
dataset = [['Eggs', 'Kidney Beans', 'Milk', 'Nutmeg', 'Onion', 'Yogurt'], ['Dill', 'Eggs', 'Kidney Beans', 'Nutmeg', 'Onion', 'Yogurt'], ['Apple', 'Eggs', 'Kidney Beans', 'Milk'], ['Corn', 'Kidney Beans', 'Milk', 'Yogurt'], ['Corn', 'Eggs', 'Ice cream', 'Kidney Beans', 'Onion'], ['Apple', 'Milk', 'Yogurt'], ['Eggs', 'Kidney Beans', 'Onion'], ['Corn', 'Dill', 'Kidney Beans', 'Nutmeg', 'Onion'], ['Apple', 'Eggs', 'Ice cream', 'Milk', 'Onion', 'Yogurt'], ['Ice cream'], ['Apple', 'Ice cream', 'Nutmeg']]

dataset
# Out:
# [['Eggs', 'Kidney Beans', 'Milk', 'Nutmeg', 'Onion', 'Yogurt'],
#  ['Dill', 'Eggs', 'Kidney Beans', 'Nutmeg', 'Onion', 'Yogurt'],
#  ['Apple', 'Eggs', 'Kidney Beans', 'Milk'],
#  ['Corn', 'Kidney Beans', 'Milk', 'Yogurt'],
#  ['Corn', 'Eggs', 'Ice cream', 'Kidney Beans', 'Onion'],
#  ['Apple', 'Milk', 'Yogurt'],
#  ['Eggs', 'Kidney Beans', 'Onion'],
#  ['Corn', 'Dill', 'Kidney Beans', 'Nutmeg', 'Onion'],
#  ['Apple', 'Eggs', 'Ice cream', 'Milk', 'Onion', 'Yogurt'],
#  ['Ice cream'],
#  ['Apple', 'Ice cream', 'Nutmeg']]

# %%
df1 = pd.DataFrame(dataset, columns = )
df1
# Out:
#             0             1             2             3      4       5
# 0        Eggs  Kidney Beans          Milk        Nutmeg  Onion  Yogurt
# 1        Dill          Eggs  Kidney Beans        Nutmeg  Onion  Yogurt
# 2       Apple          Eggs  Kidney Beans          Milk   None    None
# 3        Corn  Kidney Beans          Milk        Yogurt   None    None
# 4        Corn          Eggs     Ice cream  Kidney Beans  Onion    None
# 5       Apple          Milk        Yogurt          None   None    None
# 6        Eggs  Kidney Beans         Onion          None   None    None
# 7        Corn          Dill  Kidney Beans        Nutmeg  Onion    None
# 8       Apple          Eggs     Ice cream          Milk  Onion  Yogurt
# 9   Ice cream          None          None          None   None    None
# 10      Apple     Ice cream        Nutmeg          None   None    None

# %%
te = TransactionEncoder()

te_ary = te.fit(dataset).transform(dataset)

# %%
df = pd.DataFrame(te_ary, columns = te.columns_)
df.head()
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Yogurt
# 0    True
# 1    True
# 2   False
# 3    True
# 4   False

# %%
frequent_itemsets = apriori(df, min_support = 0.3, use_colnames = True)

frequent_itemsets
# Out:
#      support                     itemsets
# 0   0.363636                      (Apple)
# 1   0.545455                       (Eggs)
# 2   0.363636                  (Ice cream)
# 3   0.636364               (Kidney Beans)
# 4   0.454545                       (Milk)
# 5   0.363636                     (Nutmeg)
# 6   0.545455                      (Onion)
# 7   0.454545                     (Yogurt)
# 8   0.454545         (Kidney Beans, Eggs)
# 9   0.454545                (Onion, Eggs)
# 10  0.454545        (Onion, Kidney Beans)
# 11  0.363636               (Milk, Yogurt)
# 12  0.363636  (Onion, Eggs, Kidney Beans)

# %%
result = association_rules(frequent_itemsets, metric = 'confidence', min_threshold = 0.6)

result
# Out:
#               antecedents            consequents  antecedent support  \
# 0          (Kidney Beans)                 (Eggs)            0.636364
# 1                  (Eggs)         (Kidney Beans)            0.545455
# 2                 (Onion)                 (Eggs)            0.545455
# 3                  (Eggs)                (Onion)            0.545455
# 4                 (Onion)         (Kidney Beans)            0.545455
# 5          (Kidney Beans)                (Onion)            0.636364
# 6                  (Milk)               (Yogurt)            0.454545
# 7                (Yogurt)                 (Milk)            0.454545
# 8           (Onion, Eggs)         (Kidney Beans)            0.454545
# 9   (Onion, Kidney Beans)                 (Eggs)            0.454545
# 10   (Kidney Beans, Eggs)                (Onion)            0.454545
# 11                (Onion)   (Kidney Beans, Eggs)            0.545455
# 12                 (Eggs)  (Onion, Kidney Beans)            0.545455
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.545455  0.454545    0.714286  1.309524  0.107438    1.590909
# 1             0.636364  0.454545    0.833333  1.309524  0.107438    2.181818
# 2             0.545455  0.454545    0.833333  1.527778  0.157025    2.727273
# 3             0.545455  0.454545    0.833333  1.527778  0.157025    2.727273
# 4             0.636364  0.454545    0.833333  1.309524  0.107438    2.181818
# 5             0.545455  0.454545    0.714286  1.309524  0.107438    1.590909
# 6             0.454545  0.363636    0.800000  1.760000  0.157025    2.727273
# 7             0.454545  0.363636    0.800000  1.760000  0.157025    2.727273
# 8             0.636364  0.363636    0.800000  1.257143  0.074380    1.818182
# 9             0.545455  0.363636    0.800000  1.466667  0.115702    2.272727
# 10            0.545455  0.363636    0.800000  1.466667  0.115702    2.272727
# 11            0.454545  0.363636    0.666667  1.466667  0.115702    1.636364
# 12            0.454545  0.363636    0.666667  1.466667  0.115702    1.636364

# %%
result1 = result[['antecedents', 'consequents', 'support', 'confidence', 'lift']]

result1
# Out:
#               antecedents            consequents   support  confidence  \
# 0          (Kidney Beans)                 (Eggs)  0.454545    0.714286
# 1                  (Eggs)         (Kidney Beans)  0.454545    0.833333
# 2                 (Onion)                 (Eggs)  0.454545    0.833333
# 3                  (Eggs)                (Onion)  0.454545    0.833333
# 4                 (Onion)         (Kidney Beans)  0.454545    0.833333
# 5          (Kidney Beans)                (Onion)  0.454545    0.714286
# 6                  (Milk)               (Yogurt)  0.363636    0.800000
# 7                (Yogurt)                 (Milk)  0.363636    0.800000
# 8           (Onion, Eggs)         (Kidney Beans)  0.363636    0.800000
# 9   (Onion, Kidney Beans)                 (Eggs)  0.363636    0.800000
# 10   (Kidney Beans, Eggs)                (Onion)  0.363636    0.800000
# 11                (Onion)   (Kidney Beans, Eggs)  0.363636    0.666667
# 12                 (Eggs)  (Onion, Kidney Beans)  0.363636    0.666667
#
#         lift
# 0   1.309524
# 1   1.309524
# 2   1.527778
# 3   1.527778
# 4   1.309524
# 5   1.309524
# 6   1.760000
# 7   1.760000
# 8   1.257143
# 9   1.466667
# 10  1.466667
# 11  1.466667
# 12  1.466667

# %%
result1.sort_values('lift', ascending = False)
# Out:
#               antecedents            consequents   support  confidence  \
# 6                  (Milk)               (Yogurt)  0.363636    0.800000
# 7                (Yogurt)                 (Milk)  0.363636    0.800000
# 2                 (Onion)                 (Eggs)  0.454545    0.833333
# 3                  (Eggs)                (Onion)  0.454545    0.833333
# 9   (Onion, Kidney Beans)                 (Eggs)  0.363636    0.800000
# 10   (Kidney Beans, Eggs)                (Onion)  0.363636    0.800000
# 11                (Onion)   (Kidney Beans, Eggs)  0.363636    0.666667
# 12                 (Eggs)  (Onion, Kidney Beans)  0.363636    0.666667
# 0          (Kidney Beans)                 (Eggs)  0.454545    0.714286
# 5          (Kidney Beans)                (Onion)  0.454545    0.714286
# 1                  (Eggs)         (Kidney Beans)  0.454545    0.833333
# 4                 (Onion)         (Kidney Beans)  0.454545    0.833333
# 8           (Onion, Eggs)         (Kidney Beans)  0.363636    0.800000
#
#         lift
# 6   1.760000
# 7   1.760000
# 2   1.527778
# 3   1.527778
# 9   1.466667
# 10  1.466667
# 11  1.466667
# 12  1.466667
# 0   1.309524
# 5   1.309524
# 1   1.309524
# 4   1.309524
# 8   1.257143
